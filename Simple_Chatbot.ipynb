# %%
from openai import OpenAI

api_key = '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'

client = OpenAI(api_key=api_key)

completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {
            "role": "user",
            "content": "Give me 3 ideas for apps I could build with openai apis "
        }
    ]
)
print(completion.choices[0].message.content)
# Out:
# 1. A personalized writing assistant app that utilizes OpenAI's natural language processing capabilities to help users improve their writing skills. The app could provide suggestions for improving grammar, style, and tone based on the user's writing style and preferences.
#
# 2. A virtual customer service representative app that uses OpenAI's conversational AI capabilities to provide automated customer support to users. The app could answer common customer questions, solve basic problems, and help users navigate through the company's products and services.
#
# 3. A personalized news recommendation app that leverages OpenAI's machine learning models to curate and deliver news articles tailored to the user's interests and preferences. The app could use natural language processing to analyze the user's reading habits and provide personalized recommendations for articles, blogs, and news stories.
